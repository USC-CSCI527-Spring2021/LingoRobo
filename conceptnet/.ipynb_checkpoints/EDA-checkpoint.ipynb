# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
df = pd.read_csv('conceptnet-assertions-5.6.0.csv.en',sep='\t',names=['relation','head','tail','weight'])
df.head()
# Out:
#   relation       head      tail  weight
# 0  antonym   ab_extra  ab_intra     1.0
# 1  antonym   ab_intra  ab_extra     1.0
# 2  antonym  abactinal   actinal     1.0
# 3  antonym    abandon   acquire     1.0
# 4  antonym    abandon  arrogate     1.0

# %%
df.relation.value_counts().plot.pie(figsize=(10,20),legend=True)
# Out:
# <AxesSubplot:ylabel='relation'>

# %%
df.loc[df['head']== 'spatula'].head()
# Out:
#           relation     head             tail  weight
# 41063   atlocation  spatula           drawer     1.0
# 41064   atlocation  spatula          kitchen     2.0
# 274069  hascontext  spatula        chemistry     1.0
# 274070  hascontext  spatula    north_america     1.0
# 559729         isa  spatula  kitchen_utensil     1.0

# %%
df.loc[df['tail']== 'kitchen_utensil'].head()
# Out:
#        relation             head             tail  weight
# 408847      isa    cheese_cutter  kitchen_utensil     2.0
# 418978      isa    cookie_cutter  kitchen_utensil     2.0
# 419011      isa  cooking_utensil  kitchen_utensil     2.0
# 449365      isa             fork  kitchen_utensil     1.0
# 458361      isa           grater  kitchen_utensil     2.0
